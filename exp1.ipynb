# %% [markdown]
# <a href="https://colab.research.google.com/github/charu286/ML_lab/blob/exp1/exp1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
uploaded = files.upload()
# Out:
#      <input type="file" id="files-1934f758-3beb-46ce-a6b5-612758c50ccf" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-1934f758-3beb-46ce-a6b5-612758c50ccf">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import numpy as np

# %%
df=pd.read_csv('dataset.csv')

# %%
df
# Out:
#    Unnamed: 0    sky  temp humidity    wind isplay
# 0           0  sunny  warm     high  strong    yes
# 1           1  sunny  warm   normal  strong    yes
# 2           2  rainy  cold     high  strong     no
# 3           3  sunny  warm     high    less    yes

# %%
df.head()
# Out:
#    Unnamed: 0    sky  temp humidity    wind isplay
# 0           0  sunny  warm     high  strong    yes
# 1           1  sunny  warm   normal  strong    yes
# 2           2  rainy  cold     high  strong     no
# 3           3  sunny  warm     high    less    yes

# %%
df.tail()
# Out:
#    Unnamed: 0    sky  temp humidity    wind isplay
# 0           0  sunny  warm     high  strong    yes
# 1           1  sunny  warm   normal  strong    yes
# 2           2  rainy  cold     high  strong     no
# 3           3  sunny  warm     high    less    yes

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  4 non-null      int64
#  1   sky         4 non-null      object
#  2   temp        4 non-null      object
#  3   humidity    4 non-null      object
#  4   wind        4 non-null      object
#  5   isplay      4 non-null      object
# dtypes: int64(1), object(5)
# memory usage: 324.0+ bytes

# %%
df.describe()
# Out:
#        Unnamed: 0
# count    4.000000
# mean     1.500000
# std      1.290994
# min      0.000000
# 25%      0.750000
# 50%      1.500000
# 75%      2.250000
# max      3.000000

# %%
df.shape
# Out:
# (4, 6)

# %%
y=df["isplay"]

# %%
X=df.drop(columns=["isplay"])

# %%
X
# Out:
#    Unnamed: 0    sky  temp humidity    wind
# 0           0  sunny  warm     high  strong
# 1           1  sunny  warm   normal  strong
# 2           2  rainy  cold     high  strong
# 3           3  sunny  warm     high    less

# %%
y
# Out:
# 0    yes
# 1    yes
# 2     no
# 3    yes
# Name: isplay, dtype: object

# %%
type(X)
# Out:
# pandas.core.frame.DataFrame

# %%
type(y)
# Out:
# pandas.core.series.Series

# %%
X=np.array(X)

# %%
type(X)
# Out:
# numpy.ndarray

# %%
y=np.array(y)

# %%
type(y)
# Out:
# numpy.ndarray

# %%
def train(X,y):
  for i,val in enumerate(y):
    if val=='yes':
      h=X[i].copy()
      break
  for i,val in enumerate(X):
    if y[i]=='yes':
      for z in range(len(h)):
        if val[z] != h[z]:
          h[z]='?'
        else:
          pass
        return h

# %%
train(X,y)
# Out:
# array([0, 'sunny', 'warm', 'high', 'strong'], dtype=object)
